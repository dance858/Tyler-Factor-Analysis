# %%
import sys 
import pdb 
from DOA_utils import (generate_ula_data_nonuniform, RootMUSIC1D,
                       non_uniform_Gaussian_CRB, nonuniform_MVT_CRB)
import sys
sys.path.append("../../")
from estimators.N_estimators import sample_mean_and_cov_complex, Gaussian_FA_via_EM_complex
from estimators.Tyler_FA_CCP_complex import Tyler_FA_via_CCP_complex
import numpy as np
import numpy.linalg as LA
from matplotlib import pyplot as plt
seed = 43
np.random.seed(seed)

# %%
# define parameters for the experiment
snr = 5
theta_rad = np.array([0, 5, 10, 15]) * np.pi / 180
num_of_sources, power_source = len(theta_rad), 1
P = power_source * np.eye(num_of_sources)
wavelength = 1
wavelength_factor = 2
d = wavelength / wavelength_factor
num_of_sensors = 15
noise_variances = np.random.rand(num_of_sensors)
scaling = np.sum(1/noise_variances) / (snr * num_of_sensors / power_source)
noise_variances *= scaling 
all_num_of_samples = [50, 75, 100, 125, 150, 175, 200]
MC_runs = 2
all_errors_Tyler_FA_N = np.zeros((len(all_num_of_samples), MC_runs))
all_errors_S_N = np.zeros((len(all_num_of_samples), MC_runs))
all_errors_G_FA_N = np.zeros((len(all_num_of_samples), MC_runs))
all_errors_Tyler_FA_T = np.zeros((len(all_num_of_samples), MC_runs))
all_errors_S_T = np.zeros((len(all_num_of_samples), MC_runs))
all_errors_G_FA_T = np.zeros((len(all_num_of_samples), MC_runs))
degrees_of_freedom = 3

# %%
RootMusicEstimator = RootMUSIC1D(wavelength)
max_iter_CCP = 10

# %%
for signal_distribution in ['N', 'T']:
    for ii in range(len(all_num_of_samples)):
        num_of_samples = all_num_of_samples[ii]
        print(f"simulating num_of_samples = {num_of_samples}")
        for run in range(MC_runs):
            if run % 5 == 0:
                print("run: ", run)
            [Y, true_cov, A_true] = generate_ula_data_nonuniform(power_source, 
                                    noise_variances, d, num_of_sensors, 
                                    num_of_sources, num_of_samples, wavelength, 
                                    theta_rad, degrees_of_freedom, signal_distribution)

            X = Y - np.mean(Y, axis=1, keepdims=True)

            # compute covariance estimates
            S_EM = sample_mean_and_cov_complex(X)[1]
            F_G, d_G = Gaussian_FA_via_EM_complex(S_EM, num_of_sources, 100)
            
            G_Tyler, e_Tyler, all_QN_iter, H = Tyler_FA_via_CCP_complex(X, num_of_sources, max_iter_CCP, DCP=True)
            cov_Tyler = LA.inv(np.diag(e_Tyler) - G_Tyler @ G_Tyler.conj().T)
            FFH_Tyler = cov_Tyler - np.diag(1/e_Tyler) 
            
            # compute DOA:s
            doa_F_Tyler = np.flip(-RootMusicEstimator.estimate(FFH_Tyler, num_of_sources, d)[1]._locations)
            doa_F_G = np.flip(-RootMusicEstimator.estimate(F_G @ F_G.conj().T, num_of_sources, d)[1]._locations)
            doa_S = np.flip(-RootMusicEstimator.estimate(S_EM, num_of_sources, d)[1]._locations)

            Tyler_error = LA.norm(theta_rad - doa_F_Tyler)**2
            G_FA_error = LA.norm(theta_rad - doa_F_G)**2
            S_error = LA.norm(theta_rad - doa_S)**2

            #print("Tyler / G-FA / S: ", Tyler_error, G_FA_error, S_error)

            if signal_distribution == "N":
                all_errors_Tyler_FA_N[ii, run] = Tyler_error
                all_errors_G_FA_N[ii, run] = G_FA_error
                all_errors_S_N[ii, run] = S_error
            else:
                all_errors_Tyler_FA_T[ii, run] = Tyler_error
                all_errors_G_FA_T[ii, run] = G_FA_error
                all_errors_S_T[ii, run] = S_error
# Out:
# simulating num_of_samples = 50
# run:  0
# simulating num_of_samples = 75
# run:  0
# simulating num_of_samples = 100
# run:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 19
#      16 S_EM = sample_mean_and_cov_complex(X)[1]
#      17 F_G, d_G = Gaussian_FA_via_EM_complex(S_EM, num_of_sources, 100)
# ---> 19 G_Tyler, e_Tyler, all_QN_iter, H = Tyler_FA_via_CCP_complex(X, num_of_sources, max_iter_CCP, DCP=True)
#      20 cov_Tyler = LA.inv(np.diag(e_Tyler) - G_Tyler @ G_Tyler.conj().T)
#      21 FFH_Tyler = cov_Tyler - np.diag(1/e_Tyler)
#
# File ~/Documents/Research2024/covariances/Tyler-Factor-Analysis/Tyler-Factor-Analysis/experiments/DOA/../../estimators/Tyler_FA_CCP_complex.py:69, in Tyler_FA_via_CCP_complex(X, k, max_iter, DCP, G0, e0)
#      67 if G0 is None or e0 is None:
#      68     G0, e0 = Tyler_FA_init_complex(X, k)
# ---> 69 G, e, all_QN_iter, H = Tyler_FA_via_CCP__complex(X, max_iter, G0, e0, DCP)
#      70 return G, e, all_QN_iter, H
#
# File ~/Documents/Research2024/covariances/Tyler-Factor-Analysis/Tyler-Factor-Analysis/experiments/DOA/../../estimators/Tyler_FA_CCP_complex.py:103, in Tyler_FA_via_CCP__complex(X, max_iter, G0, e0, DCP)
#      99 obj = objective_complex(G, e, X, X2, n, m, k)
#     100 #print("obj / norm(grad_e) / norm(grad_G): ", obj, norm_grad_e, norm_grad_G)
#     101
#     102 # compute next iterate
# --> 103 G_new, e_new = subprob_via_DCP(grad_p_e, grad_p_G)
#     105 line_search = True
#     106 dG = G_new - G
#
# File ~/Documents/Research2024/covariances/Tyler-Factor-Analysis/Tyler-Factor-Analysis/experiments/DOA/../../estimators/Tyler_FA_CCP_complex.py:142, in subprob_via_DCP(grad_p_e, grad_p_G)
#     140 objective = cp.Minimize(-cp.log_det(block_matrix) + grad_p_e @ e + cp.real(cp.trace(G.H @ grad_p_G)))
#     141 problem = cp.Problem(objective)
# --> 142 problem.solve(verbose=False, solver = cp.MOSEK)
#     143 return G.value, e.value
#
# File ~/Documents/Research2024/covariances/Robust-FA/venv/lib/python3.8/site-packages/cvxpy/problems/problem.py:503, in Problem.solve(self, *args, **kwargs)
#     501 else:
#     502     solve_func = Problem._solve
# --> 503 return solve_func(self, *args, **kwargs)
#
# File ~/Documents/Research2024/covariances/Robust-FA/venv/lib/python3.8/site-packages/cvxpy/problems/problem.py:1073, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1070         self.unpack(chain.retrieve(soln))
#    1071         return self.value
# -> 1073 data, solving_chain, inverse_data = self.get_problem_data(
#    1074     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1075 )
#    1077 if verbose:
#    1078     print(_NUM_SOLVER_STR)
#
# File ~/Documents/Research2024/covariances/Robust-FA/venv/lib/python3.8/site-packages/cvxpy/problems/problem.py:696, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     693     s.LOGGER.info(
#     694              'Compiling problem (target solver=%s).', solver_name)
#     695     s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 696 data, inverse_data = solving_chain.apply(self, verbose)
#     697 safe_to_cache = (
#     698     isinstance(data, dict)
#     699     and s.PARAM_PROB in data
#     700     and not any(isinstance(reduction, EvalParams)
#     701                 for reduction in solving_chain.reductions)
#     702 )
#     703 self._compilation_time = time.time() - start
#
# File ~/Documents/Research2024/covariances/Robust-FA/venv/lib/python3.8/site-packages/cvxpy/reductions/chain.py:76, in Chain.apply(self, problem, verbose)
#      74     if verbose:
#      75         s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76     problem, inv = r.apply(problem)
#      77     inverse_data.append(inv)
#      78 return problem, inverse_data
#
# File ~/Documents/Research2024/covariances/Robust-FA/venv/lib/python3.8/site-packages/cvxpy/reductions/solvers/conic_solvers/mosek_conif.py:254, in MOSEK.apply(self, problem)
#     252     data[s.A] = sp.sparse.hstack([A[:, :idx], A[:, idx+total_psd:]])
#     253     data[s.C] = np.concatenate([c[:idx], c[idx+total_psd:]])
# --> 254 A_bar_data, c_bar_data = MOSEK.bar_data(A_psd, c_psd, K)
#     255 data['A_bar_data'] = A_bar_data
#     256 data['c_bar_data'] = c_bar_data
#
# File ~/Documents/Research2024/covariances/Robust-FA/venv/lib/python3.8/site-packages/cvxpy/reductions/solvers/conic_solvers/mosek_conif.py:224, in MOSEK.bar_data(A_psd, c_psd, K)
#     221         continue
#     223     A_row_coo = A_row.tocoo()
# --> 224     rows, cols, vals = vectorized_lower_tri_to_triples(A_row_coo, dim)
#     225     A_bar_data.append((i, j, (rows, cols, vals)))
#     227 c_block = c_psd[idx:idx + vec_len]
#
# File ~/Documents/Research2024/covariances/Robust-FA/venv/lib/python3.8/site-packages/cvxpy/reductions/solvers/conic_solvers/mosek_conif.py:74, in vectorized_lower_tri_to_triples(A, dim)
#      53 def vectorized_lower_tri_to_triples(A: sp.sparse.coo_matrix | list[float] | np.ndarray, dim: int) \
#      54         -> tuple[list[int], list[int], list[float]]:
#      55     """
#      56     Attributes
#      57     ----------
#    (...)
#      71         The values of the entries in the original matrix.
#      72     """
# ---> 74     if isinstance(A, sp.sparse.coo_matrix):
#      75         vals = A.data
#      76         flattened_cols = A.col
#
# KeyboardInterrupt:

# %%
# compute CRBs
CRB_N = []
CRB_T = []
for samples in all_num_of_samples:
    CRB_N.append(np.trace(non_uniform_Gaussian_CRB(P, theta_rad, noise_variances,
                                    num_of_sensors, 1 / wavelength_factor, samples)))
    CRB_T.append(np.trace(nonuniform_MVT_CRB(P, theta_rad, np.diag(noise_variances), 
                                             num_of_sensors, samples, 
                                             1 / wavelength_factor, 
                                             degrees_of_freedom)[0]))
CRB_N = np.array(CRB_N)
CRB_T = np.array(CRB_T)
# Out:
# /home/daniel/Documents/Research2024/covariances/Tyler-Factor-Analysis/Tyler-Factor-Analysis/experiments/DOA/DOA_utils.py:355: ComplexWarning: Casting complex values to real discards the imaginary part
#   F_G[row, col] = term2 / psi
# /home/daniel/Documents/Research2024/covariances/Tyler-Factor-Analysis/Tyler-Factor-Analysis/experiments/DOA/DOA_utils.py:357: ComplexWarning: Casting complex values to real discards the imaginary part
#   F[row, col] = term1 + term2

# %%
MSE_Tyler_N = np.mean(all_errors_Tyler_FA_N, axis=1)
MSE_G_FA_N = np.mean(all_errors_G_FA_N, axis=1)
MSE_S_N = np.mean(all_errors_S_N, axis=1)
MSE_Tyler_T = np.mean(all_errors_Tyler_FA_T, axis=1)
MSE_G_FA_T = np.mean(all_errors_G_FA_T, axis=1)
MSE_S_T = np.mean(all_errors_S_T, axis=1)

# %%
# Create the plot
for distribution in ['N', 'T']:
    fig, ax = plt.subplots(figsize=(10, 6))

    if distribution == "N":
        MSE_Tyler = MSE_Tyler_N
        MSE_G_FA = MSE_G_FA_N 
        MSE_S = MSE_S_N 
        CRB = CRB_N 
    else:
        MSE_Tyler = MSE_Tyler_T
        MSE_G_FA = MSE_G_FA_T
        MSE_S = MSE_S_T
        CRB = CRB_T

    # Plot MSEs with markers and error bars
    ax.semilogy(all_num_of_samples, MSE_Tyler, marker='o', linestyle='-', linewidth=4, markersize=12,  label='Tyler-FA')
    ax.semilogy(all_num_of_samples, MSE_G_FA, marker='s', linestyle='--', linewidth=4, markersize=12, label='G-FA')
    ax.semilogy(all_num_of_samples, MSE_S, marker='d', linestyle='-.', linewidth=4, markersize=12, label='SC')
    ax.semilogy(all_num_of_samples, CRB, linestyle='--', linewidth=4, label='CRB')
    ax.set_xlabel('number of samples', fontsize=24)
    ax.set_ylabel('MSE (radians)', fontsize=24)
    ax.set_xlim(45, 205)
    ax.set_ylim(1e-5, 5*1e-1)
    ax.tick_params(axis='both', which='major', labelsize=20)
    if distribution == "N":
        location = 'upper right'
    else:
        location = 'right' 
    ax.legend(loc=location, fontsize=16)
    ax.grid(True)

    # Ensure tight layout
    plt.tight_layout()

    plt.savefig(f'DOA_distribution={distribution}_CCP_iter={max_iter_CCP}.pdf')
# Out:
# /home/daniel/Documents/Research2024/covariances/Robust-FA/venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
np.savez(f"DOA_data_CCP_iter={max_iter_CCP}.npz", 
         all_errors_Tyler_FA_N=all_errors_Tyler_FA_N, all_errors_S_N=all_errors_S_N, 
         all_errors_G_FA_N = all_errors_G_FA_N, 
         all_errors_Tyler_FA_T=all_errors_Tyler_FA_T, all_errors_S_T=all_errors_S_T, 
         all_errors_G_FA_T = all_errors_G_FA_T, 
         all_num_of_samples=all_num_of_samples,
         theta_rad=theta_rad, noise_variances=noise_variances, 
         num_of_sensors=num_of_sensors, snr=snr, degrees_of_freedom=degrees_of_freedom)
